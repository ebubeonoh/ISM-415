# %%
import pandas

# %%
dir(pandas)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_is_numpy_dev',
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pandas.read_csv('IMDB-Movie-Data.csv', index_col='Title')

# %%
data
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
data.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
data.tail()
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
data.shape
# Out:
# (1000, 11)

# %%
data.isna().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.dropna(how = 'any', inplace = True)

# %%
data.isna().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # What is the average of the metascore and rating, of each movie on the list

# %%
data['Metascore'] = data['Metascore']/10

# %%
data
# Out:
#                           Rank                     Genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 Description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %%
data.insert(11, column= 'Average rating', value = data.loc[:,['Rating', 'Metascore']].mean(axis=1))

# %%
data
# Out:
#                           Rank                     Genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 Description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# # What are the top 5 highest rated movies, going by their average rating

# %%
data.sort_values(by = 'Average rating', ascending = False, inplace = True)

# %%
data
# Out:
#                           Rank                       Genre  \
# Title
# Pan's Labyrinth            231           Drama,Fantasy,War
# Boyhood                    657                       Drama
# 12 Years a Slave           112     Biography,Drama,History
# Inside Out                 242  Animation,Adventure,Comedy
# Ratatouille                490     Animation,Comedy,Family
# ...                        ...                         ...
# The Disappointments Room   238       Drama,Horror,Thriller
# Max Steel                  788     Action,Adventure,Family
# Nine Lives                1000       Comedy,Family,Fantasy
# Movie 43                   509              Comedy,Romance
# Disaster Movie             830                      Comedy
#
#                                                                 Description  \
# Title
# Pan's Labyrinth           In the falangist Spain of 1944, the bookish yo...
# Boyhood                   The life of Mason, from early childhood to his...
# ...

# %% [markdown]
# # What are the top 5  directors whose, films made the most revenue

# %%
data.sort_values(by = 'Revenue (Millions)', ascending = False, inplace = True)

# %%
data.head()
# Out:
#                                             Rank                     Genre  \
# Title
# Star Wars: Episode VII - The Force Awakens    51  Action,Adventure,Fantasy
# Avatar                                        88  Action,Adventure,Fantasy
# Jurassic World                                86   Action,Adventure,Sci-Fi
# The Avengers                                  77             Action,Sci-Fi
# The Dark Knight                               55        Action,Crime,Drama
#
#                                                                                   Description  \
# Title
# Star Wars: Episode VII - The Force Awakens  Three decades after the defeat of the Galactic...
# Avatar                                      A paraplegic marine dispatched to the moon Pan...
# Jurassic World                              A new theme park, built on the original site o...
# The Avengers                                Earth's mightiest heroes must come together an...
# ...

# %%
data[['Director', 'Revenue (Millions)']]
# Out:
#                                                      Director  \
# Title
# Star Wars: Episode VII - The Force Awakens        J.J. Abrams
# Avatar                                          James Cameron
# Jurassic World                                Colin Trevorrow
# The Avengers                                      Joss Whedon
# The Dark Knight                             Christopher Nolan
# ...                                                       ...
# Wakefield                                       Robin Swicord
# Lovesong                                          So Yong Kim
# Love, Rosie                                  Christian Ditter
# Into the Forest                               Patricia Rozema
# A Kind of Murder                                 Andy Goddard
#
#                                             Revenue (Millions)
# Title
# Star Wars: Episode VII - The Force Awakens              936.63
# Avatar                                                  760.51
# ...
